# %% [markdown]
# # 00_3. 파이썬 분석 예제 - 웹서버 장비 추가 시점 예측하기

# %% [markdown]
# ## 목표
#
# 가상 창업 회사인 MLAAS.
# * 웹상에서 기계 학습 알고리즘을 제공하는 서비스를 함.
# * 웹 요청을 처리하고자 기반 시설을 늘리려고 함
# * 비싼 장비를 무턱대로 살 수는 없다.
# * 현재 시스템은, 시간당 최대 100,000번의 요청을 처리할 수 있다.
# * 최대로 가용하며 모든 요청을 완벽하게 처리하기 위해 앞으로 클라우드에 추가 장비를 설치해야 하는 시점(시간당 100,000번을 알고 싶다

# %% [markdown]
# ## 차례
#
# * 데이터 읽기
# * 데이터 정리와 전처리
# * 적절한 모델과 학습 알고리즘 선택
#  * 모델을 만들기에 앞서
#  * 단순한 직선으로 시작하기
#  * 좀 더 복잡한 모델
#  * 일보후퇴, 이보전진 : 데이터 다시 보기
#  * 훈련과 테스트
#  * 최초 질문에 대답하기

# %% [markdown]
# ## 데이터 읽기

# %% [markdown]
# 데이터 설명 : web_traffic.tsv
# * 지난달 통계
# * 탭으로 구분됨
# * 시간당 요청 수
# * 각 줄은 연속적으로 나열된 시간, 그 시간의 요청수

# %%
# !head ./00_data/web/web_traffic.tsv
# Out:
# 1	2272
# 2	nan
# 3	1386
# 4	1365
# 5	1488
# 6	1337
# 7	1883
# 8	2283
# 9	1335
# 10	1025

# %%
import scipy as sp
data = sp.genfromtxt("./00_data/web/web_traffic.tsv", delimiter="\t")
data
# Out:
# array([[  1.00000000e+00,   2.27200000e+03],
#        [  2.00000000e+00,              nan],
#        [  3.00000000e+00,   1.38600000e+03],
#        ...,
#        [  7.41000000e+02,   5.39200000e+03],
#        [  7.42000000e+02,   5.90600000e+03],
#        [  7.43000000e+02,   4.88100000e+03]])

# %%
print(data.shape)
# Out:
# (743, 2)

# %%
data
# Out:
# array([[  1.00000000e+00,   2.27200000e+03],
#        [  2.00000000e+00,              nan],
#        [  3.00000000e+00,   1.38600000e+03],
#        ...,
#        [  7.41000000e+02,   5.39200000e+03],
#        [  7.42000000e+02,   5.90600000e+03],
#        [  7.43000000e+02,   4.88100000e+03]])

# %% [markdown]
# ## 데이터 정리와 전처리

# %%
# 743개의 데이터를 시간과 특정시간 요청수를 나타내는 2개의 벡터로 나누자
x = data[:,0]
y = data[:,1]

# %%
# 시간 정보에 잘못된 값 nan이 얼마나 포함되어 있는가?
sp.sum(sp.isnan(y))
# Out:
# 8

# %%
# 걸러내고, 유효 엔트기만 선별하자
x = x[~sp.isnan(y)]
y = y[~sp.isnan(y)]

# %%
# 데이터 형태를 파악하기 위해 그래프를 그리자
import matplotlib.pyplot as plt
plt.scatter(x,y)
plt.title("Web traffic over the last month")
plt.xlabel("Time")
plt.ylabel("Hits/hour")
plt.xticks([w*7*24 for w in range(10)],
           ['week %i'%w for w in range(10)])
plt.autoscale(tight=True)
plt.grid()
plt.show()

# %% [markdown]
# ## 적합한 모델과 학습 알고리즘 선택

# %% [markdown]
# [질문] 서버는 들어오는 웹 트래피에 얼마 동안 대응할 수 있을까?
# * 노이즈를 고려한 실제 모델 찾기
# * 모델을 사용해 설비를 증설해야 할 시점

# %% [markdown]
# ### 모델을 만들기에 앞서

# %% [markdown]
# 용어들
# * 모델 : 이론적 근사치 - 단순한 모델로 시작
# * approximation error - 근사치 오차
# * squared distance - 거리 제곱 오차 측정치

# %%
# 학습된 모델 함수 f에 대한 오차를 구하는 함수(squared distance 사용)
def error(f, x, y) : 
    return sp.sum((f(x)-y)**2)

# %% [markdown]
# ### 단순한 직선으로 시작하기

# %%
fp1, residuals, rank, sv, rcond = sp.polyfit(x, y, 1, full=True)

# %%
fp1
# Out:
# array([   2.59619213,  989.02487106])

# %%
residuals
# Out:
# array([  3.17389767e+08])

# %%
f1 = sp.poly1d(fp1)
print(error(f1, x, y))
# Out:
# 317389767.34

# %%
plt.scatter(x,y)
plt.title("Web traffic over the last month")
plt.xlabel("Time")
plt.ylabel("Hits/hour")
plt.xticks([w*7*24 for w in range(10)],
           ['week %i'%w for w in range(10)])
plt.autoscale(tight=True)

fx = sp.linspace(0, x[-1], 1000) 
plt.plot(fx, f1(fx), linewidth=4)
plt.legend(["d=%i" % f1.order], loc="upper left")

plt.grid()
plt.show()

# %% [raw]
# f(x) = 2.59619213 * x + 989.0248716

# %% [markdown]
# ### 좀 더 복잡한 모델

# %%
# 2차원 다항식 모델
f2p = sp.polyfit(x, y, 2)
f2p
# Out:
# array([  1.05322215e-02,  -5.26545650e+00,   1.97476082e+03])

# %%
f2 = sp.poly1d(f2p)
error(f2, x, y)
# Out:
# 179983507.87817919

# %%
plt.scatter(x,y)
plt.title("Web traffic over the last month")
plt.xlabel("Time")
plt.ylabel("Hits/hour")
plt.xticks([w*7*24 for w in range(10)],
           ['week %i'%w for w in range(10)])
plt.autoscale(tight=True)

fx = sp.linspace(0, x[-1], 1000)

plt.plot(fx, f1(fx), linewidth=4)
#plt.legend(["d=%i" % f1.order],loc="upper left")

plt.plot(fx, f2(fx), linewidth=4)
plt.legend([["d=%i" % f1.order],["d=%i" % f2.order]], loc="upper left")

plt.grid()
plt.show()

# %% [raw]
# f(x) = 0.0105322215 * x ** 2 - 5.26545650 * x + 1974.76082

# %%
# 실습 - 차수 3으로 도전
# 에러는?

# %%
# 실습 - 차수 10으로 도전
# 에러는?

# %%
# 실습 - 차수 50으로 도전
# 에러는?

# %%
f3p = sp.polyfit(x, y, 3)
f3 = sp.poly1d(f3p)

f10p = sp.polyfit(x, y, 10)
f10 = sp.poly1d(f10p)

f100p = sp.polyfit(x, y, 100)
f100 = sp.poly1d(f100p)


plt.scatter(x,y)
plt.title("Web traffic over the last month")
plt.xlabel("Time")
plt.ylabel("Hits/hour")
plt.xticks([w*7*24 for w in range(10)],
           ['week %i'%w for w in range(10)])
plt.autoscale(tight=True)

fx = sp.linspace(0, x[-1], 1000)

plt.plot(fx, f1(fx), linewidth=4)
plt.plot(fx, f2(fx), linewidth=4)
plt.plot(fx, f3(fx), linewidth=4)
plt.plot(fx, f10(fx), linewidth=4)
plt.plot(fx, f100(fx), linewidth=4)

plt.legend([["d=%i" % f1.order],
            ["d=%i" % f2.order],
            ["d=%i" % f3.order],
            ["d=%i" % f10.order],
            ["d=%i" % f100.order]
            ], 
           loc="upper left")

plt.grid()
plt.show()
# Out:
# /BIO/home/moodern/.venv/total/local/lib/python2.7/site-packages/numpy/lib/polynomial.py:588: RankWarning: Polyfit may be poorly conditioned
#   warnings.warn(msg, RankWarning)

# %%
for f in [f1, f2, f3, f10, f100]:
    print("Error d=%i: %f" % (f.order, error(f, x, y)))
# Out:
# Error d=1: 317389767.339778
# Error d=2: 179983507.878179
# Error d=3: 139350144.031725
# Error d=10: 121942326.363461
# Error d=53: 109452404.433121

# %% [markdown]
# #### overfitting 과적합

# %% [markdown]
# overfillting(과적합)
#
# * 위의 결과를 보면 10차 이상은 너무 굴곡이 많음.
# * 이는 모델이 너무 많은 데이터에 fitting 됨
# * 주요 데이터 뿐만 아니라 노이즈까지 반영하는 것을 overfitting이라고 한다.
#
# 다음 중에 하나 선택해야 한다.
#
# * 적합화된 다항식 모델 중 하나를 선택해야 할지
# * 스플라인spline 같은 좀 더 복잡한 모델로 바꿔야 할지
# * 데이터를 다르게 분석하고 다시 시작해야 할지

# %% [markdown]
# #### 일보후퇴, 일보전진 : 데이터 다시 보기

# %% [markdown]
# 데이터를 다시 보자

# %%
# 데이터 형태를 파악하기 위해 그래프를 그리자
import matplotlib.pyplot as plt
plt.scatter(x,y)
plt.title("Web traffic over the last month")
plt.xlabel("Time")
plt.ylabel("Hits/hour")
plt.xticks([w*7*24 for w in range(10)],
           ['week %i'%w for w in range(10)])
plt.autoscale(tight=True)
plt.grid()
plt.show()

# %% [markdown]
# * 3주차와 4주차 사이에 변곡점이 있다.
# * 3.5주차를 기준으로 데이터를 둘로 나누고 두 선을 따로 훈련하자
# * 3주차까지 첫 번째 직선을 훈련하고, 나머지를 두 번째 직선으로 훈련하자

# %%
inflection = 3.5 * 7 * 24

# %%
# 첫번째 직선
xa = x[:inflection]
ya = y[:inflection]

fa = sp.poly1d(sp.polyfit(xa, ya, 1))

plt.scatter(x,y)
plt.title("Web traffic over the last month")
plt.xlabel("Time")
plt.ylabel("Hits/hour")
plt.xticks([w*7*24 for w in range(10)],
           ['week %i'%w for w in range(10)])

fax = sp.linspace(0, xa[-1], 1000)

plt.plot(fax, fa(fax), linewidth=4)

plt.legend([["d=%i" % fa.order],
            ], 
           loc="upper left")

plt.autoscale(tight=True)
plt.grid()
plt.show()

# %%
# 두번째 직선
xb = x[inflection:]
yb = y[inflection:]

fb = sp.poly1d(sp.polyfit(xb, yb, 1))

plt.scatter(x,y)
plt.title("Web traffic over the last month")
plt.xlabel("Time")
plt.ylabel("Hits/hour")
plt.xticks([w*7*24 for w in range(10)],
           ['week %i'%w for w in range(10)])

fax = sp.linspace(0, xa[-1], 1000)
fbx = sp.linspace(xb[0], xb[-1], 1000)

plt.plot(fax, fa(fax), linewidth=4)
plt.plot(fbx, fb(fbx), linewidth=4)

plt.legend([["d=%i" % fa.order],
            ["d=%i" % fb.order]
            ], 
           loc="upper left")

plt.autoscale(tight=True)
plt.grid()
plt.show()

# %%
fa_error = error(fa, xa, ya)
fb_error = error(fb, xb, yb)
print("Error inflection=%f" %(fa_error + fb_error))
# Out:
# Error inflection=132950348.197616

# %% [markdown]
# #### 미래를 예측해보자!

# %% [markdown]
# 어느 모델을 써야 하는가?
#
# * 두 직선의 결합은 이전 모델보다 overfitting을 피한 것 처럼 보인다.
# * 하지만 여전히 고차모델보다는 오차가 높다.
# * 왜 직선 모델을 신용하는가?

# %%
colors = ['g', 'k', 'b', 'm', 'r']
linestyles = ['-', '-.', '--', ':', '-']

def plot_models(x, y, models, mx=None, ymax=None, xmin=None):
    plt.clf()
    plt.scatter(x, y, s=10)
    plt.title("Web traffic over the last month")
    plt.xlabel("Time")
    plt.ylabel("Hits/hour")
    plt.xticks(
        [w * 7 * 24 for w in range(10)], ['week %i' % w for w in range(10)])

    if models:
        if mx is None:
            mx = sp.linspace(0, x[-1], 1000)
        for model, style, color in zip(models, linestyles, colors):
            # print "Model:",model
            # print "Coeffs:",model.coeffs
            plt.plot(mx, model(mx), linestyle=style, linewidth=2, c=color)

        plt.legend(["d=%i" % m.order for m in models], loc="upper left")

    plt.autoscale(tight=True)
    plt.ylim(ymin=0)
    if ymax:
        plt.ylim(ymax=ymax)
    if xmin:
        plt.xlim(xmin=xmin)
    plt.grid(True, linestyle='-', color='0.75')
    plt.show()

# %%
# 이전 모델들의 예측력 그래프 그리기
plot_models(
    x, y, [f1, f2, f3, f10, f100],
    mx=sp.linspace(0 * 7 * 24, 6 * 7 * 24, 100),
    ymax=10000, xmin=0 * 7 * 24)

# %% [markdown]
# 예측 결과
#
# * 고차 다항식 모델 - 과적합(overfitting). 회사의 미래가 밝지 않다. 데이터를 너무 잘 반영해서 미래의 예측도 쓸모없어졌다
# * 저차 다항식 모델 - 과소적합(under-fitting). 역시 좋지 않다. 데이터를 제대로 반영하지 못하는듯.

# %%
# 마지막 주의 데이터만으로 훈련하기
fb1 = fb
fb2 = sp.poly1d(sp.polyfit(xb, yb, 2))
fb3 = sp.poly1d(sp.polyfit(xb, yb, 3))
fb10 = sp.poly1d(sp.polyfit(xb, yb, 10))
fb100 = sp.poly1d(sp.polyfit(xb, yb, 100))

print("Errors for only the time after inflection point")
for f in [fb1, fb2, fb3, fb10, fb100]:
    print("Error d=%i: %f" % (f.order, error(f, xb, yb)))

plot_models(
    x, y, [fb1, fb2, fb3, fb10, fb100], 
    mx=sp.linspace(0 * 7 * 24, 6 * 7 * 24, 100),
    ymax=10000, xmin=0 * 7 * 24)
# Out:
# Errors for only the time after inflection point
# Error d=1: 22143941.107618
# Error d=2: 19768846.989176
# Error d=3: 19766452.361027
# Error d=10: 18949296.816737
# Error d=53: 18300724.105251
# /BIO/home/moodern/.venv/total/local/lib/python2.7/site-packages/numpy/lib/polynomial.py:588: RankWarning: Polyfit may be poorly conditioned
#   warnings.warn(msg, RankWarning)
# /BIO/home/moodern/.venv/total/local/lib/python2.7/site-packages/numpy/lib/polynomial.py:588: RankWarning: Polyfit may be poorly conditioned
#   warnings.warn(msg, RankWarning)

# %% [markdown]
# 결과
#
# * 직선 모델의 경우, 마지막 주의 데이터만 학습하면 더 예측력이 높아진다(차수 낮은 모델들)
# * 고차 모델의 경우, 예측력이 더 엉망이 된다.
# * 그런데도 오차만으로 모델 판단 기준을 정하면 고차모델을 택해야 하는 것처럼 나온다.
#
# 어떻게 해야하나??!!!

# %%
print("Errors for only the time after inflection point")
for f in [fb1, fb2, fb3, fb10, fb100]:
    print("Error d=%i: %f" % (f.order, error(f, xb, yb)))
# Out:
# Errors for only the time after inflection point
# Error d=1: 22143941.107618
# Error d=2: 19768846.989176
# Error d=3: 19766452.361027
# Error d=10: 18949296.816737
# Error d=53: 18300724.105251

# %% [markdown]
# ### 훈련과 테스트

# %% [markdown]
# 가령, 모델의 정확도를 낮추는 미래의 데이터를 갖고 있더라도, 단지 결과인 근사치 오차를 바탕으로 모델을 선택할 수 있어야 한다.
#
# 홀드아웃 데이터(학습 데이터와 테스트 데이터를 분리한다) 방식!
#
# * 마지막 주의 데이터에서
# * 테스트용 데이터로 쓰기 위해 일부 데이터를 뺀다(test data set)
# * 그리고 그 나머지 데이터로 학습해서 모델을 만든다(training data set)
# * 학습 결과로 나온 모델의 성능을 테스트 데이터로 측정한다. (오차 구함)

# %%
frac = 0.3
split_idx = int(frac * len(xb))
split_idx
# Out:
# 44

# %%
shuffled = sp.random.permutation(list(range(len(xb))))
shuffled
# Out:
# array([ 80,  84,  74,  25, 123,  81,  76,  57,  63,  51, 142,  43,  37,
#         20, 105,  70, 100,  17, 135,  18, 106,  91, 131, 132,  67, 145,
#        144, 137,  61, 116, 111, 104,  11,  33,  94,  68,  99, 110,   7,
#          5, 138,  19,  97, 136,  79,  14, 126,  87, 118, 141, 122,  54,
#         12,  96,  47,  15, 117, 133,  42, 115,  52,  66,  50, 140,  59,
#         16,   1,  55,  32, 121,  75,  24,  38,  62,  77,   2,  90,  45,
#         83,   6,  44, 139,  93,  69,  26,  73,  88,  31,  64, 114,   8,
#        143,   3, 146, 124,  41,  71, 134,   4, 127,  56,  49,  92, 108,
#         27,   9,  58, 102, 109,  34,  48,  10,  46,  95,  29,  22,  89,
#         86,  21, 130,  40, 103,  82, 128,  65,  78,  85,  13, 101,  72,
#        125,  39,  36,  53, 120, 113,  98,  35,  60,   0, 112,  28, 129,
#        119,  23, 107,  30])

# %%
test = sorted(shuffled[:split_idx])
test[:10]
# Out:
# [5, 7, 11, 17, 18, 19, 20, 25, 33, 37]

# %%
train = sorted(shuffled[split_idx:])
train[:10]
# Out:
# [0, 1, 2, 3, 4, 6, 8, 9, 10, 12]

# %%
fbt1 = sp.poly1d(sp.polyfit(xb[train], yb[train], 1))
fbt2 = sp.poly1d(sp.polyfit(xb[train], yb[train], 2))
fbt3 = sp.poly1d(sp.polyfit(xb[train], yb[train], 3))
fbt10 = sp.poly1d(sp.polyfit(xb[train], yb[train], 10))
fbt100 = sp.poly1d(sp.polyfit(xb[train], yb[train], 100))

plot_models(
    x, y, [fbt1, fbt2, fbt3, fbt10, fbt100], 
    mx=sp.linspace(0 * 7 * 24, 6 * 7 * 24, 100),
    ymax=10000, xmin=0 * 7 * 24)
# Out:
# /BIO/home/moodern/.venv/total/local/lib/python2.7/site-packages/numpy/lib/polynomial.py:588: RankWarning: Polyfit may be poorly conditioned
#   warnings.warn(msg, RankWarning)
# /BIO/home/moodern/.venv/total/local/lib/python2.7/site-packages/numpy/lib/polynomial.py:588: RankWarning: Polyfit may be poorly conditioned
#   warnings.warn(msg, RankWarning)

# %% [markdown]
# 그래프상으로 d=2와 d=3이 예측력이 제일 좋아보인다.
#
# 테스트 데이터에 모델을 적용해서 오차를 구해보자.

# %%
print("Test errors for only the time after inflection point")
for f in [fbt1, fbt2, fbt3, fbt10, fbt100]:
    print("Error d=%i: %f" % (f.order, error(f, xb[test], yb[test])))
# Out:
# Test errors for only the time after inflection point
# Error d=1: 7816891.247550
# Error d=2: 6601873.329714
# Error d=3: 6841617.047519
# Error d=10: 6616979.114928
# Error d=53: 7861097.235474

# %% [markdown]
# 오차 계산 결과 d=2 모델이 가장 좋은 것으로 !!

# %% [markdown]
# ### 최초의 질문에 대답하기

# %% [markdown]
# 시간당 100,000 요청이 언제 들어올까? 장비를 언제를 기준으로 구매해야 할까?
#
# * 모델인 2차 다항식의 y값이 100,000이 되는 x를 찾으면 된다. = 다항식의 근 찾기
# * 다항식에서 100,000을 빼고 근을 구한다.

# %%
fb2 = sp.poly1d(sp.polyfit(xb[train], yb[train], 2))
print(fb2)
# Out:
#          2
# 0.06833 x - 70.73 x + 1.977e+04

# %%
print(fb2-100000)
# Out:
#          2
# 0.06833 x - 70.73 x - 8.023e+04

# %%
from scipy.optimize import fsolve
reached_max = fsolve(fb2-100000, 800)/(7*24)
reached_max
# Out:
# array([ 10.22846572])

# %%
print("100,000 hits/hour expected at week %f" % reached_max[0])
# Out:
# 100,000 hits/hour expected at week 10.228466

# %% [markdown]
# 예측결과 : 10주 뒤엔 최대 수용치(시간당 100,000번 접속)에 도달할 것이다.

# %% [markdown]
# # 정리

# %% [markdown]
# 전형적인 기계 학습 작업은
#
# * 데이터 정제와 이해에 대부분의 시간을 보낸다.
# * 올바른 실험 준비가 필요하다.
# * 훈련과 테스트가 섞이지 않아야 한다.

# %% [markdown]
# ## 참고자료
#
#  * [1] Building Machine Learning Systems with Python(한국어판) - http://www.kyobobook.co.kr/product/detailViewKor.laf?mallGb=KOR&ejkGb=KOR&linkClass=&barcode=9788960775367
